# %% [markdown]
# # <font color=red>Intro to Python

# %%
# Bir paragraf açıklama (Koda başlarken en azından 1 cümle ile bu açıklamayı yapmak gerekiyor)
# Bu projede Pandas ve Python çalışıyoruz.
# Latec yazabiliyoruz altta bir örneği mevcut $$ arasına yazabilirsin. (Matematiksel ifade)
#overlaf.com/latex/templates adresinden kitap makale cv thez yazma gibi şeylere ulaşabilirsin

# %% [markdown]
# $ \int_a^b \frac{dx}{sinx} \Delta \Sigma$

# %%
# Shift enter ile kod çalıştırılır
# ESC a ile üste ESC b ile alta bir satır ekleyebilirsin

# %% [markdown]
# ### Değişken tanımlama

# %%
a=5
b=3
c=a*b  # Değişkenleri bu şekilde tanımlıyoruz ve bundan sonraki her yerde a ve b tanımlanmış oluyor

# %%
print(c)
# Out:
# 15

# %%
yil=2011   #mesela değikeni böyle tanımladın ve yıl lazım olan yerlere yıl değişkenini yazarsan en baştaki yili değiştirmenle herşeyi değiştirebilirsin

# %%
yil
# Out:
# 2011

# %%
print()  # Print parantez açıp kapatman lazm bunları değişken olarak kullanamazsın içine yazacağın yazıları tırnak içinde yazman lazım

# %%
print('Merhaba')
# Out:
# Merhaba

# %%
for i in range(1000):  # for döngüsü istemiyoruz
    print('merhaba')
# Out:
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# ...

# %%
'Merhaba'*10   # for ile aynı işi yaptı
# Out:
# 'MerhabaMerhabaMerhabaMerhabaMerhabaMerhabaMerhabaMerhabaMerhabaMerhaba'

# %%
# for döngüsü aynı işi tekrar ediyorsa kullanılıyor

# %%
# Veri Tipleri
# 1-String = Yazı metin text, sözel veri bunları tek, çift veya üç tırnak içinde yazıyoruz
#2- Integer = Tam sayı
#3-float = Ondalıklı sayı

# %%
d="Dünya"
d='Dünya'
d='''Dünya'''
# İçinde tek tırnak kullancağımız yerlerde çift tırnak içinde tek tırnak kullanmalıyız
d="O'Conor"
d='''Ali'nin babası dediki "Merhaba"'''

# %%
# Listeler  (İçinde birden fazla değer bulundururlar)

# %%
liste1=[1,4,6,'Ali','Veli']   # Köşeli parantez içinde olacak

# %%
liste1
# Out:
# [1, 4, 6, 'Ali', 'Veli']

# %%
#Dictionary  (Kelime var ve açıklaması var)(Sözlük) ({} parantez kullanacaz)

# %%
sozluk={'key':'açıklaması'}

# %%
sozluk
# Out:
# {'key': 'açıklaması'}

# %%
for i in liste1:
    print(i)      # Liste içini yazacak
# Out:
# 1
# 4
# 6
# Ali
# Veli

# %%
# Fonksiyonlar  (Bir işlem yapıp sonucunu bize döndürürler)

# %%
fiyat=[25,67,99,100,80]

# %%
# DRY - DO not repeat yourself

# %%
def Vergi(x):
    return x*1.6

# %%
Vergi(78)
# Out:
# 124.80000000000001

# %%
for i in fiyat:
    print(Vergi(i))    # For ile yazımı
# Out:
# 40.0
# 107.2
# 158.4
# 160.0
# 128.0

# %%
# List Comprehension

# %%
[Vergi(x) for x in fiyat]
# Out:
# [40.0, 107.2, 158.4, 160.0, 128.0]

# %%
[x**2 for x in range(11)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Operatörler

# %%
# Aritmetik Operatörler + - * / %(Modüler Aritmetik Bölümden Kalan) **(Üs Alma)

# %%
# Logic Operatorler (Mantıksal) <,>,==,!=(EşitDeğil), and or &

# %%
import pandas as pd     # pandasa pd kısayolunu atıyoruz

# %%
#df   Dataframe Dataları okurken bunu kullanıyoruz
df=pd.read_csv('train.csv')    # pd.read_csv ile okuma işlemini yapıyoruz df dediğimiz şeye bu train dosyasını tanımladık

# %%
df.head() # Exceldeki ilk 5 datayı görmemizi sağlıyor
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape # Verinin kaç satır stündan oluştuğunu gösterir
# Out:
# (891, 12)

# %%
df.tail() #Sondan 5 satırı gösterir
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.plot() # Tüm verilerin grafiğini çizer
# Out:
# <AxesSubplot:>

# %%
toplam=0
c=0
for i in df['Age']:
    toplam=toplam+i
    c=c+1
avg=toplam/c

# %%
print(avg)
# Out:
# nan

# %%
df.describe() # Bütün stünların ortalaması vs hepsini hesaplıyor istatistiği yaptık
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr()   # Korelayson yapıyor
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df['Gender'].nunique()     # bu iki tane cinsiyet olduğunu söylüyor
# Out:
# 2

# %%
df['Gender']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Gender, Length: 891, dtype: object

# %%
df['Gender'].value_counts()    #Kaç tane kadın kaç tane erkek var onu sayıyor
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
# Parantez açıp kapatıyoruz bu fonksiyonlarda yapıoyr bir işlem yapıyor parantez yoksa bu özellik soruyor

# %%
df[df['Age']<18]    # 18 yaşından küçüklerin listesi
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.columns=df.columns.str.upper()    # Stün isimlerini büyük harfe çevirdik

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2=pd.read_excel('sales-funnel.xlsx')

# %%
pip install xlrd    #Excel dosyalarını okumak için gerekli eklenti
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#Excel'

# %%
df2=pd.read_excel('sales-funnel.xlsx')

# %%
df2.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df3=pd.read_xml('catalog.xml')

# %%
df3.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df4=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)')[2]    #İnternetten bir siteden tablo çekebiliyoruz Sondaki 2 ile 3. tabloyu çektik

# %%
df4.head()
# Out:
#   Country/Territory IMF[1][12]            World Bank[13]             \
#   Country/Territory   Forecast       Year       Estimate       Year
# 0             World  113795678       2025      111326370       2024
# 1     United States   30507217       2025       29184890       2024
# 2             China   19231705  [n 1]2025       18743803  [n 3]2024
# 3           Germany    4744804       2025        4659929       2024
# 4             India    4187017       2025        3912686       2024
#
#   United Nations[14]
#             Estimate       Year
# 0          100834796       2022
# 1           27720700       2023
# 2           17794782  [n 1]2023
# 3            4525704       2023
# 4            3575778       2023

# %%
# Tabloyu excele aktarmak için
df4.to_excel('gdp.xlsx')     # to_excel ile tabloyu excle aktardık

# %%
pip install gtts    # Robotları konuşturma
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#'

# %%
from gtts import gTTS

# %%
text='Yapay zeka dersimizi nasıl buldunuz? Eğlenceli değil mi?'
kayit=gTTS(text=text,lang='tr',slow=False)
kayit.save('robot.mp3')

# %%
df=pd.read_csv('train.csv')

# %%
import seaborn as sns    #Grafik çizdirme paketi

# %%
sns.pairplot(df,hue='Gender')    # Grafik çizdirme komutu

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 960F-0421
#
#  Directory of C:\Users\ibrahim\Documents\Yapay Zeka\Day1
#
# 13.07.2025  12:06    <DIR>          .
# 12.07.2025  19:06    <DIR>          ..
# 12.07.2025  11:28    <DIR>          .ipynb_checkpoints
# 12.07.2025  11:06             6.681 catalog.xml
# 12.07.2025  11:06               335 Courses.json
# 12.07.2025  11:06               518 data.xml
# 12.07.2025  11:06            11.658 excel-comp-data.xlsx
# 13.07.2025  12:05            18.043 gdp.xlsx
# 13.07.2025  12:06           934.751 Intro to Python - Pythona GiriŸ.ipynb
# 13.07.2025  12:05            42.432 robot.mp3
# 12.07.2025  11:06             5.552 sales-estimate.xlsx
# 12.07.2025  11:06             5.680 sales-funnel.xlsx
# 12.07.2025  12:16    <DIR>          Source
# 12.07.2025  11:06                40 test_pandas.csv
# 12.07.2025  11:06            36.864 test_pandas.db
# 12.07.2025  11:06            30.093 test_pandas.xlsm
# ...

# %%
df=pd.read_excel('sales-funnel.xlsx')

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df=pd.read_xml('catalog.xml')

# %%
df.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df=pd.read_clipboard()    # Chromeda beğendiğin tabloları ctrl c ile kopyaladığında hafızada ki tabloyu almaya yarıyor

# %%
df
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
df.to_excel('internettablo.xlsx')
