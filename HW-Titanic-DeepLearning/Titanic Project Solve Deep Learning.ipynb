# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 960F-0421
#
#  Directory of C:\Users\ibrahim\Documents\Yapay Zeka\HW-Titanic-DeepLearning
#
# 01.08.2025  20:33    <DIR>          .
# 30.07.2025  20:01    <DIR>          ..
# 30.07.2025  20:04    <DIR>          .ipynb_checkpoints
# 01.08.2025  20:33            84.601 Titanic Project Solve Deep Learning.ipynb
# 26.07.2025  07:21            28.629 ttest.csv
# 26.07.2025  07:22            61.194 ttrain.csv
#                3 File(s)        174.424 bytes
#                3 Dir(s)  89.243.987.968 bytes free

# %%
df_train=pd.read_csv('ttest.csv')

# %%
df_test=pd.read_csv('ttrain.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.shape
# Out:
# (418, 11)

# %%
df_test.shape
# Out:
# (891, 12)

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=pd.concat([df_train,df_test])

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Survived        418
# dtype: int64

# %%
del df['Cabin']    # Kabinde çok fazla boş veri olduğu için sildim

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# Survived       418
# dtype: int64

# %%
del df['Name']

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# Survived       418
# dtype: int64

# %%
del df['Embarked']

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Survived       418
# dtype: int64

# %%
del df['Ticket']

# %%
df.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare  Survived
# 0          892       3    male  34.5      0      0   7.8292       NaN
# 1          893       3  female  47.0      1      0   7.0000       NaN
# 2          894       2    male  62.0      0      0   9.6875       NaN
# 3          895       3    male  27.0      0      0   8.6625       NaN
# 4          896       3  female  22.0      1      1  12.2875       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Sex          1309 non-null   object
#  3   Age          1046 non-null   float64
#  4   SibSp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Fare         1308 non-null   float64
#  7   Survived     891 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 92.0+ KB

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df1=df['Survived']

# %%
df1.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Survived, dtype: float64

# %%
df = df.drop(columns=['Survived'])  # 'Survived' sütununu silip yeni DataFrame oluştur

# %%
df.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male
# 0          892       3  34.5      0      0   7.8292         1
# 1          893       3  47.0      1      0   7.0000         0
# 2          894       2  62.0      0      0   9.6875         1
# 3          895       3  27.0      0      0   8.6625         1
# 4          896       3  22.0      1      1  12.2875         0

# %%
age_data = df[['Age']]

# %%
lr=LinearRegression()
imp=IterativeImputer(estimator=lr)
imputed_data=imp.fit_transform(age_data)

# %%
imputed_df = pd.DataFrame(imputed_data, columns=['Age'])

# %%
df['Age'] = imputed_df['Age']

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# Sex_male       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male
# 0          892       3  34.5      0      0   7.8292         1
# 1          893       3  47.0      1      0   7.0000         0
# 2          894       2  62.0      0      0   9.6875         1
# 3          895       3  27.0      0      0   8.6625         1
# 4          896       3  22.0      1      1  12.2875         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Age          1309 non-null   float64
#  3   SibSp        1309 non-null   int64
#  4   Parch        1309 non-null   int64
#  5   Fare         1308 non-null   float64
#  6   Sex_male     1309 non-null   uint8
# dtypes: float64(2), int64(4), uint8(1)
# memory usage: 72.9 KB

# %%
df1.isnull().sum()
# Out:
# 418

# %%
df.shape
# Out:
# (1309, 7)

# %%
df1.shape
# Out:
# (1309,)

# %%
df1.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Survived, dtype: float64

# %%
df1.tail()
# Out:
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, dtype: float64

# %%
df['Survived']=df1

# %%
df.shape
# Out:
# (1309, 8)

# %%
df.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male  Survived
# 0          892       3  34.5      0      0   7.8292         1       NaN
# 1          893       3  47.0      1      0   7.0000         0       NaN
# 2          894       2  62.0      0      0   9.6875         1       NaN
# 3          895       3  27.0      0      0   8.6625         1       NaN
# 4          896       3  22.0      1      1  12.2875         0       NaN

# %%
df.tail()
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch   Fare  Sex_male  Survived
# 886          887       2  29.881138      0      0  13.00         1       0.0
# 887          888       1   0.750000      0      0  30.00         0       1.0
# 888          889       3  29.881138      1      2  23.45         0       0.0
# 889          890       1  38.000000      0      0  30.00         1       1.0
# 890          891       3  33.000000      0      0   7.75         1       0.0

# %%
lr=LinearRegression()
imp=IterativeImputer(estimator=lr)
imputed_data=imp.fit_transform(df[['Fare']])

# %%
imputed_data
# Out:
# array([[ 7.8292],
#        [ 7.    ],
#        [ 9.6875],
#        ...,
#        [23.45  ],
#        [30.    ],
#        [ 7.75  ]])

# %%
pd.DataFrame(imputed_data)
# Out:
#             0
# 0      7.8292
# 1      7.0000
# 2      9.6875
# 3      8.6625
# 4     12.2875
# ...       ...
# 1304  13.0000
# 1305  30.0000
# 1306  23.4500
# 1307  30.0000
# 1308   7.7500
#
# [1309 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age              0
# SibSp            0
# Parch            0
# Fare             1
# Sex_male         0
# Survived       418
# dtype: int64

# %%
df['Fare']=imputed_data

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Sex_male         0
# Survived       418
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Age          1309 non-null   float64
#  3   SibSp        1309 non-null   int64
#  4   Parch        1309 non-null   int64
#  5   Fare         1309 non-null   float64
#  6   Sex_male     1309 non-null   uint8
#  7   Survived     891 non-null    float64
# dtypes: float64(3), int64(4), uint8(1)
# memory usage: 83.1 KB

# %%
df.shape
# Out:
# (1309, 8)

# %%
from sklearn.preprocessing import normalize,scale

# %%
df.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male  Survived
# 0          892       3  34.5      0      0   7.8292         1       NaN
# 1          893       3  47.0      1      0   7.0000         0       NaN
# 2          894       2  62.0      0      0   9.6875         1       NaN
# 3          895       3  27.0      0      0   8.6625         1       NaN
# 4          896       3  22.0      1      1  12.2875         0       NaN

# %%
test=df[:892]

# %%
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male  Survived
# 0          892       3  34.5      0      0   7.8292         1       NaN
# 1          893       3  47.0      1      0   7.0000         0       NaN
# 2          894       2  62.0      0      0   9.6875         1       NaN
# 3          895       3  27.0      0      0   8.6625         1       NaN
# 4          896       3  22.0      1      1  12.2875         0       NaN

# %%
train=df[892:]

# %%
train.head()
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male  Survived
# 474          475       3  21.0      0      0   9.8375         0       0.0
# 475          476       1  28.5      0      0  52.0000         1       0.0
# 476          477       2   5.0      1      0  21.0000         1       0.0
# 477          478       3  11.0      1      0   7.0458         1       0.0
# 478          479       3  22.0      0      0   7.5208         1       0.0

# %%
x=train.drop(['Survived','PassengerId'],axis=1)

# %%
y=train[['Survived']]

# %%
x.head()
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Sex_male
# 474       3  21.0      0      0   9.8375         0
# 475       1  28.5      0      0  52.0000         1
# 476       2   5.0      1      0  21.0000         1
# 477       3  11.0      1      0   7.0458         1
# 478       3  22.0      0      0   7.5208         1

# %%
y.head()
# Out:
#      Survived
# 474       0.0
# 475       0.0
# 476       0.0
# 477       0.0
# 478       0.0

# %%
normalized=normalize(x)

# %%
pd.DataFrame(normalized)
# Out:
#             0         1         2       3         4         5
# 0    0.128297  0.898079  0.000000  0.0000  0.420707  0.000000
# 1    0.016859  0.480487  0.000000  0.0000  0.876678  0.016859
# 2    0.092057  0.230144  0.046029  0.0000  0.966603  0.046029
# 3    0.222593  0.816174  0.074198  0.0000  0.522782  0.074198
# 4    0.127855  0.937604  0.000000  0.0000  0.320524  0.042618
# ..        ...       ...       ...     ...       ...       ...
# 412  0.061231  0.914827  0.000000  0.0000  0.398002  0.030616
# 413  0.033304  0.024978  0.000000  0.0000  0.999133  0.000000
# 414  0.078600  0.782888  0.026200  0.0524  0.614391  0.000000
# 415  0.020646  0.784548  0.000000  0.0000  0.619380  0.020646
# 416  0.088119  0.969305  0.000000  0.0000  0.227640  0.029373
#
# [417 rows x 6 columns]

# %%
pip install tensorflow
# Out:
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.
# miceforest 6.0.3 requires pandas>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# ansys-mapdl-core 0.68.4 requires numpy<2.0.0,>=1.14.0; python_version >= "3.9", but you have numpy 2.0.2 which is incompatible.

# %%
import numpy as np

# %%
pip install --upgrade numpy pandas
# Out:
# ...
#   Using cached pandas-2.3.1-cp39-cp39-win_amd64.whl (11.4 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip uninstall numpy pandas -y
# !pip install numpy==1.24.4 pandas==1.5.3
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: pandas 2.3.1
# Uninstalling pandas-2.3.1:
#   Successfully uninstalled pandas-2.3.1
# ...
#   Using cached numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
# ...
#   Using cached pandas-1.5.3-cp39-cp39-win_amd64.whl (10.9 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.4 which is incompatible.
# miceforest 6.0.3 requires pandas>=2.1.0, but you have pandas 1.5.3 which is incompatible.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import pandas as pd
import numpy as np

# %%
y.head()
# Out:
#      Survived
# 474       0.0
# 475       0.0
# 476       0.0
# 477       0.0
# 478       0.0

# %%
x.head()
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Sex_male
# 474       3  21.0      0      0   9.8375         0
# 475       1  28.5      0      0  52.0000         1
# 476       2   5.0      1      0  21.0000         1
# 477       3  11.0      1      0   7.0458         1
# 478       3  22.0      0      0   7.5208         1

# %%
model=Sequential()   
model.add(Dense(7,activation='relu'))     #İlk 120 neronu bağlamış olduk,, relu veri önemliyse 1 in üstnde geliyor önemsizse es geçiyor
model.add(Dense(200,activation='relu'))     # 2. layerı oluşturuyoruz
model.add(Dense(400,activation='relu'))     # 3. layerı oluşturduk
model.add(Dense(150,activation='relu'))      # 4. layerı oluşturduk
model.add(Dense(100,activation='relu'))       # 5. layerı oluşturduk
model.add(Dense(1,activation='sigmoid'))    # Son layerı oluşturduk Classifaction da sonuç evet veya hayır olacağı için sigmoid kullandık
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(x,y, epochs=500,batch_size=32,validation_split=0.1,verbose=1)   # Verbose 0 dersek aşağıdaki sonucu göstermez
# Out:
# Epoch 1/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8758 - loss: 0.2622 - val_accuracy: 0.8333 - val_loss: 0.8955
# Epoch 2/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8860 - loss: 0.2439 - val_accuracy: 0.8571 - val_loss: 0.9773
# Epoch 3/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8579 - loss: 0.3027 - val_accuracy: 0.7857 - val_loss: 0.8275
# Epoch 4/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8751 - loss: 0.2907 - val_accuracy: 0.7857 - val_loss: 0.7880
# Epoch 5/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8979 - loss: 0.2919 - val_accuracy: 0.8333 - val_loss: 0.7002
# Epoch 6/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8517 - loss: 0.3721 - val_accuracy: 0.8095 - val_loss: 0.7299
# Epoch 7/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8544 - loss: 0.3349 - val_accuracy: 0.8333 - val_loss: 0.7894
# Epoch 8/500
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])    # accuracy nin grafikte ki değişimi
plt.plot(history.history['val_accuracy'])

# %%
# Eğitim kaybını ve doğruluğunu çizme
plt.figure(figsize=(12, 5))

# Kayıp grafiği
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Kayıp Grafiği')
plt.xlabel('Epoch')
plt.ylabel('Kayıp')
plt.legend()

# Doğruluk grafiği
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Doğruluk Grafiği')
plt.xlabel('Epoch')
plt.ylabel('Doğruluk')
plt.legend()

plt.show()

# %%
# Test verisi ile modelin doğruluğunu değerlendirme
test_loss, test_accuracy = model.evaluate(x, y)
print(f'Test Kaybı: {test_loss}, Test Doğruluğu: {test_accuracy}')
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9043 - loss: 0.2383
# Test Kaybı: 0.2979762554168701, Test Doğruluğu: 0.8992805480957031

# %%
# Yeni veriler üzerinde tahmin yapma
predictions = model.predict(x)

# Tahmin sonuçlarını gösterme
print(predictions[:10])  # İlk 10 tahmini göster
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[3.0896511e-02]
#  [6.1478272e-02]
#  [3.2697619e-05]
#  [2.5522812e-10]
#  [1.5604261e-01]
#  [9.9996036e-01]
#  [6.8852882e-21]
#  [1.2423647e-05]
#  [1.8836355e-02]
#  [1.6854724e-02]]

# %%
# Eğitim sonuçlarını inceleme
print(history.history)
# Out:
# {'accuracy': [0.871999979019165, 0.871999979019165, 0.8453333377838135, 0.874666690826416, 0.874666690826416, 0.8506666421890259, 0.8560000061988831, 0.8560000061988831, 0.8560000061988831, 0.8693333268165588, 0.8613333106040955, 0.8693333268165588, 0.8826666474342346, 0.8773333430290222, 0.8613333106040955, 0.8613333106040955, 0.8613333106040955, 0.8826666474342346, 0.8826666474342346, 0.8693333268165588, 0.8799999952316284, 0.8826666474342346, 0.8853333592414856, 0.8853333592414856, 0.8773333430290222, 0.890666663646698, 0.8773333430290222, 0.8826666474342346, 0.8826666474342346, 0.890666663646698, 0.8880000114440918, 0.8773333430290222, 0.874666690826416, 0.8799999952316284, 0.8506666421890259, 0.871999979019165, 0.8773333430290222, 0.871999979019165, 0.890666663646698, 0.8853333592414856, 0.8826666474342346, 0.8640000224113464, 0.8586666584014893, 0.890666663646698, 0.8960000276565552, 0.8853333592414856, 0.8853333592414856, 0.8880000114440918, 0.8986666798591614, 0.8933333158493
# ...

# %%
# Eğitim verisi üzerinde tahmin yapma
predictions = model.predict(x)

# Tahminleri 0 veya 1'e dönüştürme (binary sınıflandırma için)
predicted_classes = (predictions > 0.5).astype(int)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
import pandas as pd

# Gerçek etiketleri DataFrame'e dönüştürme
results = pd.DataFrame({
    'Gerçek': y.values.flatten(),  # Gerçek etiketler
    'Tahmin': predicted_classes.flatten()  # Tahmin edilen sınıf
})

# İlk birkaç satırı görüntüleme
print(results.head())
# Out:
#    Gerçek  Tahmin
# 0     0.0       0
# 1     0.0       0
# 2     0.0       0
# 3     0.0       0
# 4     0.0       0

# %%
# Tüm sonuçları görüntülemek için
print(results)
# Out:
#      Gerçek  Tahmin
# 0       0.0       0
# 1       0.0       0
# 2       0.0       0
# 3       0.0       0
# 4       0.0       0
# ..      ...     ...
# 412     0.0       0
# 413     1.0       1
# 414     0.0       1
# 415     1.0       0
# 416     0.0       0
#
# [417 rows x 2 columns]

# %%
# Sütunları yeniden düzenleme
results = results[['Tahmin', 'Gerçek']]  # Tahmin önce, gerçek sonra

# %%
results.to_csv('dtahmin_sonuclari.csv', index=False)  # CSV dosyasına kaydetme

# %%
results.tail()
# Out:
#      Tahmin  Gerçek
# 412       0     0.0
# 413       1     1.0
# 414       1     0.0
# 415       0     1.0
# 416       0     0.0

# %%
results.sample()
# Out:
#      Tahmin  Gerçek
# 398       0     0.0

# %%
results.head(30)
# Out:
#     Tahmin  Gerçek
# 0        0     0.0
# 1        0     0.0
# 2        0     0.0
# 3        0     0.0
# 4        0     0.0
# 5        1     1.0
# 6        0     0.0
# 7        0     0.0
# 8        0     0.0
# 9        0     1.0
# 10       1     1.0
# 11       0     0.0
# 12       1     1.0
# 13       0     0.0
# 14       0     0.0
# 15       1     1.0
# 16       0     0.0
# 17       0     0.0
# 18       0     0.0
# 19       0     0.0
# 20       0     0.0
# 21       0     0.0
# 22       1     1.0
# 23       0     0.0
# 24       0     0.0
# 25       0     0.0
# 26       0     0.0
# 27       0     0.0
# 28       0     0.0
# 29       0     0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
r=RandomForestClassifier()
g=GradientBoostingClassifier()

# %%
r.fit(x,y)
# Out:
# C:\Users\ibrahim\AppData\Local\Temp\ipykernel_106376\2591809438.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r.fit(x,y)
# RandomForestClassifier()

# %%
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_male  Survived
# 0          892       3  34.5      0      0   7.8292         1       NaN
# 1          893       3  47.0      1      0   7.0000         0       NaN
# 2          894       2  62.0      0      0   9.6875         1       NaN
# 3          895       3  27.0      0      0   8.6625         1       NaN
# 4          896       3  22.0      1      1  12.2875         0       NaN

# %%
test=test.drop(['PassengerId','Survived'],axis=1)

# %%
test.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male
# 0       3  34.5      0      0   7.8292         1
# 1       3  47.0      1      0   7.0000         0
# 2       2  62.0      0      0   9.6875         1
# 3       3  27.0      0      0   8.6625         1
# 4       3  22.0      1      1  12.2875         0

# %%
tahmin=r.predict(test)    # test ve x in yapısı aynı olmalı
# Tahminleri yaptık

# %%
sonuc=pd.DataFrame()

# %%
sonuc['Survived']=tahmin

# %%
df2=pd.read_csv('ttest.csv')

# %%
sonuc['Survived']=sonuc['Survived'].astype('int32')   # Sonuc floattı integera çevirdik

# %%
sonuc.head()
# Out:
#    Survived  PassengerId
# 0         0        892.0
# 1         1        893.0
# 2         1        894.0
# 3         0        895.0
# 4         1        896.0

# %%
sonuc.to_csv('sonuc3.csv', index=False)
