# %%
pip install pycaret

# %%
# Regression

# %%
from pycaret.regression import*

# %%
import pandas as pd

# %%
df=pd.read_pickle('kc_house.pkl')

# %%
setup(data=df,target='price')
# Out:
# <style type="text/css">
# #T_527bc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_527bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_527bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_527bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_527bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_527bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_527bc_row0_col1" class="data row0 col1" >450</td>
#     </tr>
#     <tr>
#       <th id="T_527bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_527bc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_527bc_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_527bc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_876be th {
#   text-align: left;
# }
# ...

# %%
# Feature engineering kendisi yapıyor fakat insan kadar domain olmayabilir

# %%
# Classification

# %%
df=pd.read_csv('pima-indians-diabetes.csv')

# %%
from pycaret.classification import*

# %%
setup(data=df,target='Outcome')
# Out:
# <style type="text/css">
# #T_f19de_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f19de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f19de_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f19de_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f19de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f19de_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f19de_row0_col1" class="data row0 col1" >4072</td>
#     </tr>
#     <tr>
#       <th id="T_f19de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f19de_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f19de_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_f19de_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_efdc0 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('lr')
# Out:
# <style type="text/css">
# #T_bced9_row10_col0, #T_bced9_row10_col1, #T_bced9_row10_col2, #T_bced9_row10_col3, #T_bced9_row10_col4, #T_bced9_row10_col5, #T_bced9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bced9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bced9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bced9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bced9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bced9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bced9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bced9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bced9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model,plot='feature')

# %%
#Clustering

# %%
df=pd.read_excel('cars.xls')

# %%
df.shape
# Out:
# (804, 12)

# %%
from pycaret.clustering import*

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_727ac_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_727ac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_727ac_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_727ac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_727ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_727ac_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_727ac_row0_col1" class="data row0 col1" >445</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_727ac_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_727ac_row1_col1" class="data row1 col1" >(804, 12)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans=create_model('kmeans',4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b099b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b099b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b099b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b099b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b099b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b099b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b099b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b099b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b099b_row0_col0" class="data row0 col0" >0.3382</td>
#       <td id="T_b099b_row0_col1" class="data row0 col1" >544.7697</td>
# ...

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans,plot='elbow')

# %%
plot_model(kmeans,plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
