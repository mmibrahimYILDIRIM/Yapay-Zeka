# %%
pip install cvlib
# Out:
# ...
#      -------------------------------------- 13.1/13.1 MB 512.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046369 sha256=c15788efbbd43c8b2a58b1a507410457e77be54b9c0019fa5da6121ab27f9909
#   Stored in directory: c:\users\ibrahim\appdata\local\pip\cache\wheels\96\ad\4c\d80d4bf4143c154ab297e2384915c89aff43d77d1787b9a702
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12067 sha256=6ef79d6195b660c205e2bf5c14320d1eba690d57e81c905040b8809d4d6c9976
#   Stored in directory: c:\users\ibrahim\appdata\local\pip\cache\wheels\d7\d9\89\a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built cvlib progressbar
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ibrahim\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ibrahim\anaconda3\lib\site-packages)
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox

# %%
img=cv2.imread('cars.jpg')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)
# Out:
# ...
#   0% |                                                                        |
# ...
#  99% |####################################################################### |
# ...
# 100% |                                                                        |

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car')
# Out:
# 11

# %%
label.count('person')
# Out:
# 1

# %%
img=cv2.imread('g8.jpg')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('person')
# Out:
# 6

# %%
img=cv2.imread('dogs.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('dog')
# Out:
# 4

# %%
img=cv2.imread('mutfak.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
# IP webcam app uygulamasıyla cep telefonundan gelen görüntüleri tanıtabiliyoruz
