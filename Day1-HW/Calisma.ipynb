# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 960F-0421
#
#  Directory of C:\Users\ibrahim\Documents\Yapay Zeka\Day1-HW
#
# 13.07.2025  14:09    <DIR>          .
# 13.07.2025  13:30    <DIR>          ..
# 13.07.2025  14:09    <DIR>          .ipynb_checkpoints
# 13.07.2025  14:09                72 Calisma.ipynb
# 12.07.2025  14:06               487 client_list.csv
# 12.07.2025  14:06               487 client_list.table
# 12.07.2025  14:06               840 client_list.txt
# 12.07.2025  14:06               449 client_list_practice.csv
# 12.07.2025  14:06               369 customer_id_list.csv
# 12.07.2025  18:53           111.970 Data Analysis with Pandas.ipynb
# 12.07.2025  18:21             1.430 df_out.csv
# 12.07.2025  18:21             2.672 df_out.p
# 12.07.2025  14:06                 0 Icon_
# 12.07.2025  14:06               400 purchase_log.csv
# 12.07.2025  14:07    <DIR>          Source
#               11 File(s)        119.176 bytes
# ...

# %%
df=pd.read_csv('client_list.csv')

# %%
df.head()
# Out:
#   first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 0   Jennifer     Jones      F   27      black     brown
# 1      Jaime   Roberts      M   32      brown     hazel
# 2    Michael   Johnson      M   55        red     green
# 3       Mary     Adams      F   42     blonde      blue
# 4     Robert  Phillips      M   37     blonde     brown

# %%
df.tail()
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 9    Jennifer     Smith      F   36      black     brown
# 10    Michael     Smith      M   37      black     hazel
# 11    Jessica    Rabbit      F   19      black      blue
# 12      Molly    Bryant      F   21      brown      blue
# 13      Jaime  Anderson      F   46      brown     green

# %%
df.sample()
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 12      Molly    Bryant      F   21      brown      blue

# %%
df.describe()
# Out:
#              Age
# count  14.000000
# mean   36.357143
# std    14.457402
# min    18.000000
# 25%    22.500000
# 50%    36.500000
# 75%    45.000000
# max    60.000000

# %%
df.max()
# Out:
# first_name    Thomas
# LAST_NAME      Smith
# gender             M
# Age               60
# Hair_COLOR       red
# eye_Color      hazel
# dtype: object

# %%
df.isnull().sum()
# Out:
# first_name    0
# LAST_NAME     0
# gender        0
# Age           0
# Hair_COLOR    0
# eye_Color     0
# dtype: int64

# %%
df.shape
# Out:
# (14, 6)

# %%
df.loc[3:11]
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 3        Mary     Adams      F   42     blonde      blue
# 4      Robert  Phillips      M   37     blonde     brown
# 5      Thomas     Moore      M   60      brown      blue
# 6     Natalie    Potter      F   21      brown     green
# 7      Brenda     Jones      F   18     blonde     brown
# 8     Michael     Smith      M   58      brown     brown
# 9    Jennifer     Smith      F   36      black     brown
# 10    Michael     Smith      M   37      black     hazel
# 11    Jessica    Rabbit      F   19      black      blue

# %%
df.iloc[3:11]
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 3        Mary     Adams      F   42     blonde      blue
# 4      Robert  Phillips      M   37     blonde     brown
# 5      Thomas     Moore      M   60      brown      blue
# 6     Natalie    Potter      F   21      brown     green
# 7      Brenda     Jones      F   18     blonde     brown
# 8     Michael     Smith      M   58      brown     brown
# 9    Jennifer     Smith      F   36      black     brown
# 10    Michael     Smith      M   37      black     hazel

# %%
df[df['LAST_NAME']=='Adams']
# Out:
#   first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 3       Mary     Adams      F   42     blonde      blue

# %%
df['LAST_NAME']
# Out:
# 0        Jones
# 1      Roberts
# 2      Johnson
# 3        Adams
# 4     Phillips
# 5        Moore
# 6       Potter
# 7        Jones
# 8        Smith
# 9        Smith
# 10       Smith
# 11      Rabbit
# 12      Bryant
# 13    Anderson
# Name: LAST_NAME, dtype: object

# %%
df[['LAST_NAME','gender']]
# Out:
#    LAST_NAME gender
# 0      Jones      F
# 1    Roberts      M
# 2    Johnson      M
# 3      Adams      F
# 4   Phillips      M
# 5      Moore      M
# 6     Potter      F
# 7      Jones      F
# 8      Smith      M
# 9      Smith      F
# 10     Smith      M
# 11    Rabbit      F
# 12    Bryant      F
# 13  Anderson      F

# %%
del df['first_name']

# %%
df
# Out:
#    LAST_NAME gender  Age Hair_COLOR eye_Color
# 0      Jones      F   27      black     brown
# 1    Roberts      M   32      brown     hazel
# 2    Johnson      M   55        red     green
# 3      Adams      F   42     blonde      blue
# 4   Phillips      M   37     blonde     brown
# 5      Moore      M   60      brown      blue
# 6     Potter      F   21      brown     green
# 7      Jones      F   18     blonde     brown
# 8      Smith      M   58      brown     brown
# 9      Smith      F   36      black     brown
# 10     Smith      M   37      black     hazel
# 11    Rabbit      F   19      black      blue
# 12    Bryant      F   21      brown      blue
# 13  Anderson      F   46      brown     green

# %%
df[df['Age']<42]
# Out:
#    LAST_NAME gender  Age Hair_COLOR eye_Color
# 0      Jones      F   27      black     brown
# 1    Roberts      M   32      brown     hazel
# 4   Phillips      M   37     blonde     brown
# 6     Potter      F   21      brown     green
# 7      Jones      F   18     blonde     brown
# 9      Smith      F   36      black     brown
# 10     Smith      M   37      black     hazel
# 11    Rabbit      F   19      black      blue
# 12    Bryant      F   21      brown      blue

# %%
sns.countplot()
# Out:
# <AxesSubplot:ylabel='count'>
